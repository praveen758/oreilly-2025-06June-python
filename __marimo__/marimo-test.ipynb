# %%
import marimo as mo

# %%
import numpy as np
import pandas as pd
from pandas import Series, DataFrame

# %%
np.random.seed(0)
s = Series(np.random.randint(0, 100, 10),
          index=list('abcdefghij'))
threshold = mo.ui.slider(0, 100)

# %%
(
    s
    .loc[lambda s_: s_ > threshold.value]
    .plot.line()
)
